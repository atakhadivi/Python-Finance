# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import yfinance as yf

# %%
#Get stock symbol
symbol = input("Enter stock symbol: ")  

# Download stock data 
data = yf.download(symbol, start='2010-01-01')  
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.470740
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.481929
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.378825
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.367033
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.409363
# ...                ...         ...         ...         ...         ...
# 2024-02-05  188.149994  189.250000  185.839996  187.679993  187.440811
# 2024-02-06  186.860001  189.309998  186.770004  189.300003  189.058762
# 2024-02-07  190.639999  191.050003  188.610001  189.410004  189.168625
# 2024-02-08  189.389999  189.539993  187.350006  188.320007  188.080017
# 2024-02-09  188.649994  189.990005  188.000000  188.850006  188.850006
#
#                Volume
# Date
# ...

# %%
X = data.reset_index()[['Date', 'Close']] 
y = data['Close']

# %%
# Convert Date to numeric days since first date
X['Date'] = (X['Date'] - X['Date'].min()).dt.days 

# Ensure other columns are numeric 
X = X.astype({'Close': 'float'})
y = y.astype('float')

# %%
# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Create and train linear regression model
model = LinearRegression()  
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions on test set
predictions = model.predict(X_test)

# %%
# Evaluate predictions vs actual close prices
error = abs(predictions - y_test)  
print('Average error:', round(error.mean(), 2))
print('Model accuracy:', round(100 - (error.mean()/y_test.mean()*100), 2), '%')
# Out:
# Average error: 0.0
# Model accuracy: 100.0 %
